# %% [markdown]
# <a href="https://colab.research.google.com/github/iavdic/ai-science-training-series/blob/main/04_intro_to_llms/11032024_Irma_Avdic_HW_Session4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Homework
#
# 1. Load in a generative model using the HuggingFace pipeline and generate text using a batch of prompts.
#   * Play with generative parameters such as temperature, max_new_tokens, and the model itself and explain the effect on the legibility of the model response. Try at least 4 different parameter/model combinations.
#   * Models that can be used include:
#     * `google/gemma-2-2b-it`
#     * `microsoft/Phi-3-mini-4k-instruct`
#     * `meta-llama/Llama-3.2-1B`
#     * Any model from this list: [Text-generation models](https://huggingface.co/models?pipeline_tag=text-generation)
#     * `gpt2` if having trouble loading these models in
#   * This guide should help! [Text-generation strategies](https://huggingface.co/docs/transformers/en/generation_strategies)
# 2. Load in 2 models of different parameter size (e.g. GPT2, meta-llama/Llama-2-7b-chat-hf, or distilbert/distilgpt2) and analyze the BertViz for each. How does the attention mechanisms change depending on model size?

# %% [markdown]
# ## Homework: Irma Avdic

# %% [markdown]
# 1. Loading in a generative model using the HuggingFace pipeline and generating text using a batch of prompts. Model used: gpt2

# %%
# Step 1: Import necessary libraries
from transformers import pipeline

# Step 2: Load the generative model
model_name = "gpt2"
text_generator = pipeline("text-generation", model=model_name)

# Step 3: Define a batch of prompts
prompts = [
    "Explain large language models to a fourth grader.",
    "Write a short story about a cow that can talk.",
    "What are the main downsides of drinking coffee?",
    "Describe the potential outcomes of the 2024 election."
]

# Step 4: Generate text with different parameter combinations

# Configuration 1: Low temperature, moderate token limit
output1 = text_generator(prompts, temperature=0.3, max_new_tokens=50, top_k=50)

# Configuration 2: High temperature, longer token limit
output2 = text_generator(prompts, temperature=0.9, max_new_tokens=100, top_k=100)

# Configuration 3: Moderate temperature, short token limit
output3 = text_generator(prompts, temperature=0.7, max_new_tokens=30, top_p=0.9)

# Configuration 4: High temperature and high diversity
output4 = text_generator(prompts, temperature=1.2, max_new_tokens=75, top_p=0.8)

# Step 5: Print and compare outputs
print("Configuration 1:")
for i, text in enumerate(output1):
    print(f"Prompt {i + 1}: {text[0]['generated_text']}")

print("\nConfiguration 2:")
for i, text in enumerate(output2):
    print(f"Prompt {i + 1}: {text[0]['generated_text']}")

print("\nConfiguration 3:")
for i, text in enumerate(output3):
    print(f"Prompt {i + 1}: {text[0]['generated_text']}")

print("\nConfiguration 4:")
for i, text in enumerate(output4):
    print(f"Prompt {i + 1}: {text[0]['generated_text']}")
# Out:
# Configuration 1:
# Prompt 1: Explain large language models to a fourth grader.
#
# In this course, you will learn how to create a language model for a language. You will be able to use the language model to create a language model for your students.
#
# You will learn how to use the language model to create
# Prompt 2: Write a short story about a cow that can talk.
#
# I'm not sure if this is a good idea, but I'm sure it's a good idea.
#
# The cow will talk to you.
#
# You will be able to tell her what you want.
#
# You will be
# Prompt 3: What are the main downsides of drinking coffee?
#
# The main downsides of drinking coffee are:
#
# 1. It's hard to get the right amount of caffeine.
#
# 2. It's hard to get the right amount of caffeine.
#
# 3. It's hard to get
# Prompt 4: Describe the potential outcomes of the 2024 election.
#
# "The election of President Trump is a significant milestone in our nation's history," said President Barack Obama. "We must continue to build on the progress we have made in the last four years, and we must continue to build on our progress
#
# Configuration 2:
# Prompt 1: Explain large language models to a fourth grader. Using multiple languages, you can find out something about what is needed, how you want it to be created, and where the work will lead.
#
# You now have a foundation that will help you learn as much as possible about languages and the techniques they use to learn them.
#
# Make sure you keep the language model learning in mind:
#
# When you create a language, expect your program to go through various types of pre-requisites. In particular, you will need to know how to
# Prompt 2: Write a short story about a cow that can talk. A story about a cow that can't. A story about a cow that can't talk. Can you play with a cow?
#
# A cow.
#
# What about a cow?" We all know how they've been. Yes, they've passed all their cattle over -- they've gotten rid of their horses -- what would you call their pets, whether they've been all that fancy with their cars? They're all just the same. It's just that they were all the same and they
# Prompt 3: What are the main downsides of drinking coffee?
#
# Marijuana vs. coffee. I have never had any of these issues. I could hardly talk about them the first time, but that just makes it harder. I also like having a better sense of where I'm at.
#
# "When you're all feeling good of yourself, that's the best thing about good eating — like an effortless flow of energy from brain chemistry will all go back to the brain chemistry." -- Andrew Leland
#
# There are also many good reasons
# Prompt 4: Describe the potential outcomes of the 2024 election. As he explains in his new book, "The Future of Our Future: The Role of Political Parties," candidates are "stirred" by uncertainty and corruption in policymaking, especially when those parties are under pressure for changes through their own institutions or through competing candidates.
#
# Trump, who would eventually be forced to follow Mitt Romney and George W. Bush, rejects this notion. During the primaries, he took great pains to point out that not all Republican candidates have "the same political DNA."
#
# Configuration 3:
# Prompt 1: Explain large language models to a fourth grader. This is a problem with the standard curriculum, which is designed to teach students how to write languages and how to use them.
#
# Do you think
# Prompt 2: Write a short story about a cow that can talk.
#
# Write a short story about a cow that can talk. Write a short story about a cow that can talk. Write a short story about a
# Prompt 3: What are the main downsides of drinking coffee?
#
# Coffee is a great source of vitamin B6, which is necessary for good health.
#
# It is also an excellent source of
# Prompt 4: Describe the potential outcomes of the 2024 election.
#
# The first step in implementing the mandate is to find a way to keep the people of the United States involved.
#
# The United States has
#
# Configuration 4:
# Prompt 1: Explain large language models to a fourth grader.
#
# This module is useful to keep track of all the classes used in your language in order to find out if the class you are writing to is the first one you are going to write. You may want to create and create your own classes for those types of questions.
#
# See Also: Language Types and Types with Classes
#
# Example 1: Listing 9.
# Prompt 2: Write a short story about a cow that can talk. It's pretty cool.
#
# The other week I went to one of the great places in California that has all of these good food places, where you can eat all of them. There are amazing restaurants. The food is good, the service is good, and the atmosphere is pretty relaxed.
#
# You know how you feel about the state of California? It has been
# Prompt 3: What are the main downsides of drinking coffee?
#
# Drinking coffee is a big one, and coffee drinking is something you can do as part of your training as an athletic runner. You may not be as smart or as strong as a better-known runner like a Kenyan runner or a World War II hero like the Great Plains runner like Andy Samberg, but you'll be as good at your craft as someone you
# Prompt 4: Describe the potential outcomes of the 2024 election.
#
#
# Q. Your analysis of what is already a national issue was published in January 2016 by the Wall Street Journal. In 2016, more than half the national electorate was African-American or Asian-American, and many were black and Latino, and the majority (51%) were in either a Democratic Party presidential primary or primary or general election. Do you think that the U

# %% [markdown]
# **Configuration 1: low temperature, moderate token limit**
#
# *   Repetitive but relevant
# *   Relatively cohesive output and fairly concise
#
# **Configuration 2: high temperature, longer token limit**
#
# *   More random than config. 1 but still relevant
# *   Longer responses than config. 1
#
# **Configuration 3: moderate temperature, short token limit**
#
# *   As random as config 2
# *   Moderately long and coherent responses
#
# **Configuration 4: high temperature, high diversity**
#
# *   The most random configuration
# *   Long and incoherent responses

# %% [markdown]
# 2. Loading in 2 models of different parameter size (e.g. GPT2, meta-llama/Llama-2-7b-chat-hf, or distilbert/distilgpt2) and analyzing the BertViz for each

# %%
from transformers import AutoTokenizer, AutoModel, utils, AutoModelForCausalLM

from bertviz import model_view
utils.logging.set_verbosity_error()  # Suppress standard warnings

model_name = 'openai-community/gpt2'
input_text = "Winter is coming."
model = AutoModelForCausalLM.from_pretrained(model_name, output_attentions=True)
tokenizer = AutoTokenizer.from_pretrained(model_name)
inputs = tokenizer.encode(input_text, return_tensors='pt')  # Tokenize input text
outputs = model(inputs)  # Run model
attention = outputs[-1]  # Retrieve attention from model outputs
tokens = tokenizer.convert_ids_to_tokens(inputs[0])  # Convert input ids to token strings
model_view(attention, tokens)  # Display model view
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-bc7545581d00407e9e6687fa58ee0141" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
utils.logging.set_verbosity_error()  # Suppress standard warnings

model_name = 'distilbert/distilgpt2'
input_text = "Winter is coming."
model = AutoModelForCausalLM.from_pretrained(model_name, output_attentions=True)
tokenizer = AutoTokenizer.from_pretrained(model_name)
inputs = tokenizer.encode(input_text, return_tensors='pt')  # Tokenize input text
outputs = model(inputs)  # Run model
attention = outputs[-1]  # Retrieve attention from model outputs
tokens = tokenizer.convert_ids_to_tokens(inputs[0])  # Convert input ids to token strings
model_view(attention, tokens)  # Display model view
# Out:
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-e72165dbb599408eb41abfa60307b2b2" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %% [markdown]
# From the above example, the attention mechanism for the smaller model, though faster, less frequently captures the fullstop at the end of the sentence than a larger model, suggesting the smaller model is not as well equipped to cpature context and details.
